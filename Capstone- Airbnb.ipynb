# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
listing1 = pd.read_csv('C:/Users/ivans/Desktop/Cyberdata/Airbnb/listings-NY.csv')
listing2 = pd.read_csv('C:/Users/ivans/Desktop/Cyberdata/Airbnb/listings(1).csv')
calendar = pd.read_csv('C:/Users/ivans/Desktop/Cyberdata/Airbnb/calendar-NY.csv')
neighbourhoods1 = pd.read_csv('C:/Users/ivans/Desktop/Cyberdata/Airbnb/neighbourhoods-NY.csv')
reviews1 = pd.read_csv('C:/Users/ivans/Desktop/Cyberdata/Airbnb/reviews-NY.csv')
reviews2 = pd.read_csv('C:/Users/ivans/Desktop/Cyberdata/Airbnb/reviews(1).csv')
neighbourhoods2 = pd.read_json('C:/Users/ivans/Desktop/Cyberdata/Airbnb/neighbourhoods.geojson', )

# %%
print listing1.shape
print listing2.shape
print calendar.shape
print neighbourhoods1.shape
print neighbourhoods2.shape
print reviews1.shape
print reviews2.shape
# Out:
# (47854, 96)
# (47854, 16)
# (17466710, 4)
# (230, 2)
# (233, 2)
# (980757, 6)
# (980757, 2)

# %%
listing1.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2515  https://www.airbnb.com/rooms/2515  20180705133528   2018-07-06
# 1  2539  https://www.airbnb.com/rooms/2539  20180705133528   2018-07-05
#
#                                  name  \
# 0    Stay at Chez Chic budget room #1
# 1  Clean & quiet apt home by the park
#
#                                              summary  \
# 0  Step into our artistic spacious apartment and ...
# 1           Renovated apt home in elevator building.
#
#                                                space  \
# 0  -PLEASE BOOK DIRECTLY. NO NEED TO SEND A REQUE...
# 1  Spacious, renovated, and clean apt home, one b...
#
#                                          description experiences_offered  \
# 0  Step into our artistic spacious apartment and ...                none
# 1  Renovated apt home in elevator building. Spaci...                none
#
#                              neighborhood_overview        ...          \
# ...

# %%
listing1.columns
# Out:
# Index([u'id', u'listing_url', u'scrape_id', u'last_scraped', u'name',
#        u'summary', u'space', u'description', u'experiences_offered',
#        u'neighborhood_overview', u'notes', u'transit', u'access',
#        u'interaction', u'house_rules', u'thumbnail_url', u'medium_url',
#        u'picture_url', u'xl_picture_url', u'host_id', u'host_url',
#        u'host_name', u'host_since', u'host_location', u'host_about',
#        u'host_response_time', u'host_response_rate', u'host_acceptance_rate',
#        u'host_is_superhost', u'host_thumbnail_url', u'host_picture_url',
#        u'host_neighbourhood', u'host_listings_count',
#        u'host_total_listings_count', u'host_verifications',
#        u'host_has_profile_pic', u'host_identity_verified', u'street',
#        u'neighbourhood', u'neighbourhood_cleansed',
#        u'neighbourhood_group_cleansed', u'city', u'state', u'zipcode',
#        u'market', u'smart_location', u'country_code', u'country', u'latitude',
# ...

# %%
listing2.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2515    Stay at Chez Chic budget room #1     2758     Steph
# 1  2539  Clean & quiet apt home by the park     2787      John
#
#   neighbourhood_group neighbourhood   latitude  longitude     room_type  \
# 0           Manhattan        Harlem  40.799205 -73.953676  Private room
# 1            Brooklyn    Kensington  40.647486 -73.972370  Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0     59               2                169  2018-05-22               1.43
# 1    149               1                  7  2017-09-17               0.22
#
#    calculated_host_listings_count  availability_365
# 0                               3               306
# 1                               7               365

# %%
calendar.head(2)
# Out:
#    listing_id        date available   price
# 0        2515  2019-07-05         t  $89.00
# 1        2515  2019-07-04         t  $89.00

# %%
neighbourhoods.head(2)
# Out:
#   neighbourhood_group neighbourhood
# 0               Bronx      Allerton
# 1               Bronx    Baychester

# %%
reviews1.head(2)
# Out:
#    listing_id   id        date  reviewer_id reviewer_name  \
# 0        2515  198  2008-10-13         2603         Jenny
# 1        2515  859  2009-03-08         8455        Roland
#
#                                             comments
# 0  Stephanie was a wonderful host! Her apartment ...
# 1  Such a wonderful place and very close to the m...

# %%
reviews2.head(2)
# Out:
#    listing_id        date
# 0        2515  2008-10-13
# 1        2515  2009-03-08

# %%
neighbourhoods1.head(2)
# Out:
#   neighbourhood_group neighbourhood
# 0               Bronx      Allerton
# 1               Bronx    Baychester

# %%
neighbourhoods2.head(2)
# Out:
#                                             features               type
# 0  {u'geometry': {u'type': u'MultiPolygon', u'coo...  FeatureCollection
# 1  {u'geometry': {u'type': u'MultiPolygon', u'coo...  FeatureCollection

# %%
# Out:
# {u'geometry': {u'coordinates': [[[[-73.782822, 40.843919],
#      [-73.782572, 40.843295],
#      [-73.782607, 40.843286],
#      [-73.782785, 40.843755],
#      [-73.783092, 40.843685],
#      [-73.782874, 40.843124],
#      [-73.782901, 40.843118],
#      [-73.783133, 40.843697],
#      [-73.782807, 40.843779],
#      [-73.782842, 40.843895],
#      [-73.782842, 40.843895],
#      [-73.782869, 40.843891],
#      [-73.782942, 40.843792],
#      [-73.782983, 40.843767],
#      [-73.783475, 40.843655],
#      [-73.783192, 40.842868],
#      [-73.783045, 40.842896],
#      [-73.783245, 40.843472],
#      [-73.78321, 40.843479],
#      [-73.783009, 40.842902],
#      [-73.782911, 40.842922],
#      [-73.782895, 40.84287],
#      [-73.783139, 40.842822],
#      [-73.783117, 40.842771],
#      [-73.782917, 40.842806],
#      [-73.782899, 40.842775],
#      [-73.783124, 40.842736],
#      [-73.783017, 40.842605],
#      [-73.782888, 40.842495],
#      [-73.782733, 40.842522],
# ...

# %%
neighbourhoods2['1'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[0])
neighbourhoods2['2'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[1])
neighbourhoods2['3'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[2])
neighbourhoods2['4'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-61183ffe34cb> in <module>()
# ----> 1 neighbourhoods2['1'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[0])
#       2 neighbourhoods2['2'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[1])
#       3 neighbourhoods2['3'] = neighbourhoods2['features'].apply(lambda x: x.split(':')[2])
#       4 neighbourhoods2['4']= neighbourhoods2['features'].apply(lambda x: x.split(':')[3])
#
# D:\Users\ivans\Anaconda2\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# ...
